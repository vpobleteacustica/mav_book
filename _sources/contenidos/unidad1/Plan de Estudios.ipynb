# %% [markdown]
# # Plan de Estudios

# %% [markdown]
# <font size="2" face="Arial">
#
# <table align="left" style="width:95%">
#
#   <tr style="outline: thin solid">
#     <td colspan="4"><div style="text-align: center; "><strong>ESQUEMA SINÓPTICO DEL PLAN DE ESTUDIOS</strong>       </div>
#     </td>
#   </tr>
#
#   <tr>
#     <th style="outline: thin solid" bgcolor="lightgray"><div style="text-align: center; "><strong>SEMESTRE 1*</strong></div></th>
#     <th style="outline: thin solid" bgcolor="lightgray"><div style="text-align: center; "><strong>SEMESTRE 2</strong></div></th>
#     <th style="outline: thin solid" bgcolor="lightgray"><div style="text-align: center; "><strong>SEMESTRE 3</strong></div></th>
#     <th style="outline: thin solid" bgcolor="lightgray"><div style="text-align: center; "><strong>SEMESTRE 4</strong></div></th>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: center; ">ACUS 301: Vibroacústica
# (3 créditos)</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Electivo 1**</div></td>
#     <td style="outline: thin solid"; rowspan="5"><div style="text-align: center; ">Tesis</div></td>
#     <td style="outline: thin solid"; rowspan="4"><div style="text-align: center; ">Tesis</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: center; ">ACUS 302: Instrumentación en acústica y vibraciones
# (3 créditos)</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Electivo 2
# **</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: center; ">MATM 310:
# Métodos matemáticos en ingeniería
# (4 créditos)</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Electivo 3
# **</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: center; ">GCIN 331: Seminario de investigación e innovación en ingeniería
# (1 crédito)</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">ACUS 397:
# Seminario de Tesis
# (2 créditos)
# ***</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: center; ">Idioma
# ****</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Proyecto de Tesis
# ****</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Examen de Grado
# ****</div></td>
#   </tr>
#
#   <tr style="outline: thin solid">
#     <td colspan="4"><br><div style="text-align: justify; "><sup>*</sup> Los cursos del currículum obligatorio se dictan cada año en el periodo agosto-diciembre que es, formalmente, el periodo de inicio de las actividades del programa.</div><br>
#
# <div style="text-align: justify; "><sup>**</sup>  Los estudiantes deben completar 9 créditos en cursos electivos. Si bien el MAV cuenta con una oferta específica de asignaturas electivas propias y directamente afines a los objetivos, perfil de egreso y líneas de investigación del programa, en la Universidad Austral de Chile la oferta íntegra de cursos de postgrado se encuentra disponible como optativos para los estudiantes de los demás programas, en la medida en que tales asignaturas dispongan de cupos y los interesados cumplan con los requisitos exigidos en dichos cursos.</div><br>
#
# <div style="text-align: justify; "><sup>***</sup>  A contar de 2018, los estudiantes que ingresan al programa vía articulación pregrado-magíster, cursan esta actividad como trabajo final de titulación.</div><br>
#
# <div style="text-align: justify; "><sup>****</sup>  Las actividades Idioma, Proyecto de Tesis y Examen de Grado corresponden a hitos en el Plan de Estudios y se califican cualitativamente como aprobadas (A) o reprobadas (R). En el caso de la actividad Idioma, los estudiantes rinden un examen de suficiencia de inglés. Quienes no aprueban el examen, deben cursar el Programa de Inglés para Estudiantes de Postgrado habilitado desde la Dirección de Estudios de Postgrado.</div><br>
#     </td>
#   </tr>
# </table>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## Actividades curriculares (resguardar consistencia con información del Anexo 5)

# %% [markdown]
# <font size="2" face="Arial">
# <table align="left" style="width:95%" border="1">
#
#   <tr style="outline: thin solid">
#     <td colspan="2"><div style="text-align: left; "><strong>3.3.2a Actividades curriculares</strong>                  </div>
#     </td>
#   </tr>
#
#   <tr>
#     <th style="outline: thin solid" bgcolor="white"><div style="text-align: center; "><strong>Actividades curriculares</strong></div></th>
#     <th style="outline: thin solid" bgcolor="white"><div style="text-align: center; "><strong>Créditos</strong></div></th>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Cursos obligatorios</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">10</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Cursos electivos</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">9</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Seminarios (2)</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">3</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Idioma (suficiencia de inglés)*</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Sin créditos</div></td>
#   </tr>
#
#    <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Proyecto de Tesis*</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Sin créditos</div></td>
#   </tr>
#
#    <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Tesis*</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">10</div></td>
#   </tr>
#
#    <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Examen de Grado*</div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Sin créditos</div></td>
#   </tr>
#
#    <tr>
#     <td style="outline: thin solid" bgcolor="lightgrey"><div style="text-align: justify; ">Total creditaje del programa, según definición de crédito/unidad equivalente propia
# </div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">32</div></td>
#   </tr>
#
#    <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Duración teórica del programa
# </div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">Cuatro semestres</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: justify; ">Duración total en horas de trabajo efectivo presencial y no presencial (horas cronológicas)
# </div></td>
#     <td style="outline: thin solid"><div style="text-align: center; ">3120</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: left; ">Definición crédito/unidad equivalente propia del programa
# </div></td>
#     <td style="outline: thin solid"><div style="text-align: justify; "><strong>“Crédito [UACh]”</strong> es una expresión cuantitativa del trabajo del estudiante. Se asigna un crédito por (a) cada hora pedagógica de clase teórica o (b) cada dos horas pedagógicas prácticas con sus correspondientes horas de estudio. Una hora pedagógica = 0,75 horas cronológicas. Un semestre tiene una duración oficial de 17 semanas.</div></td>
#   </tr>
#
#   <tr>
#     <td style="outline: thin solid"><div style="text-align: justify; "><strong>Total equivalencia del creditaje del programa, según el Sistema de Créditos Transferibles</strong>
# </div></td>
#     <td style="outline: thin solid"><div style="text-align: center; "><strong>120</strong></div></td>
#   </tr>
#
#  <tr style="outline: thin solid">
#   <td colspan="2"><div style="text-align: justify; "><sup>*</sup> Las actividades Idioma, Proyecto de Tesis y Examen de Grado corresponden a hitos en el Plan de Estudios y se califican cualitativamente como aprobadas (A) o reprobadas (R). En el caso de la actividad Idioma, los estudiantes rinden un examen de suficiencia de inglés antes del término del periodo lectivo. Quienes no aprueban satisfactoriamente la suficiencia de idioma mediante el examen, deben cursar el Programa de Inglés para Estudiantes de Postgrado habilitado desde la Dirección de Estudios de Postgrado.</div>
# </td>
# </table>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ### Tabla 3.3.2b Desglose de actividades curriculares obligatorias y electivas (Anexo 5)

# %% [markdown]
# <font size="2" face="Arial" >
# <table align="left" style="width:95%" border="1">
#   <tr style="outline: thin solid">
#   <tr bgcolor="lightgray">
#   <td rowspan="2" border: solid 4px black;><div style="text-align: center; "><strong>Nombre de</strong></div><div style="text-align: center; "><strong>la actividad curricular</strong></div></td>
#   <td rowspan="2"><div style="text-align: center; "><strong>Académico(s)</strong></div><div style="text-align: center; "><strong> a cargo</strong></div></td>
#   <td rowspan="2"><div style="text-align: center; "><strong>Carácter</strong></div></td>
#   <td colspan="3"><div style="text-align: center; "><strong>Carga horaria</strong></div><div style="text-align: center; "><strong> (horas cronológicas)</strong></div><div style="border: 1px solid black"></div></td>
#   <td colspan="2"><div style="text-align: center; "><strong>Créditos</strong></div><div style="text-align: center; "><strong> totales</strong></div><div style="border: 1px solid black"></div></td>
#   <td rowspan="2"><div style="text-align: center; "><strong>Período</strong></div></td>
#  </tr>
#
#  <tr>
#   <td bgcolor="lightgray"><div style="text-align: center; "><strong>Carga horaria presencial</strong></div> </td>
#   <td bgcolor="lightgray"><div style="text-align: center; "><strong>Carga horaria de trabajo autónomo</strong></div></td>
#   <td bgcolor="lightgray"><div style="text-align: center; "><strong>Carga horaria total</strong></div> </td>
#   <td bgcolor="lightgray"><div style="text-align: center; "><strong>Créditos UACh</strong></div> </td>
#   <td bgcolor="lightgray"><div style="text-align: center; "><strong>SCT</strong></div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 301:</div><div style="text-align: left; ">Vibroacústica</div>     </td>
#   <td><div style="text-align: center; ">Jorge Arenas</div> </td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Primer semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 302:</div><div style="text-align: left; ">Instrumentación en acústica y vibraciones</div>     </td>
#   <td><div style="text-align: center; ">José Luis Barros</div> </td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Primer semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">MATM 310:</div><div style="text-align: left; ">Métodos matemáticos en ingeniería</div>     </td>
#   <td><div style="text-align: center; ">Patricio Mella</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">51</div></td>
#   <td><div style="text-align: center; ">183</div></td>
#   <td><div style="text-align: center; ">234</div></td>
#   <td><div style="text-align: center; ">4</div></td>
#   <td><div style="text-align: center; ">9</div></td>
#   <td><div style="text-align: center; ">Primer semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">GCIN 331: </div><div style="text-align: left; ">Seminario de investigación innovación en ingeniería</div>     </td>
#   <td><div style="text-align: center; ">Enrique Suárez</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">14</div></td>
#   <td><div style="text-align: center; ">64</div></td>
#   <td><div style="text-align: center; ">78</div></td>
#   <td><div style="text-align: center; ">1</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">Primer semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 397:</div><div style="text-align: left; ">Seminario de tesis</div></td>
#   <td><div style="text-align: center; ">Profesores del claustro del programa</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">26</div></td>
#   <td><div style="text-align: center; ">104</div></td>
#   <td><div style="text-align: center; ">130</div></td>
#   <td><div style="text-align: center; ">2</div></td>
#   <td><div style="text-align: center; ">5</div></td>
#   <td><div style="text-align: center; ">Primer semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 310:</div><div style="text-align: left; ">Acústica Forense </div></td>
#   <td><div style="text-align: center; ">Jorge Sommerhoff, Claudia Rosas</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 311:</div><div style="text-align: left; "> Control de Ruido Ambiental</div></td>
#   <td><div style="text-align: center; ">Enrique Suárez</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 332:</div><div style="text-align: left; ">Teoría Avanzada de Vibraciones</div></td>
#   <td><div style="text-align: center; ">Jorge Arenas</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 340:</div><div style="text-align: left; "> Análisis de Señales en Acústica y Vibraciones </div></td>
#   <td><div style="text-align: center; ">Víctor Poblete</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 351:</div><div style="text-align: left; "> Acústica Musical</div></td>
#   <td><div style="text-align: center; ">Felipe Otondo</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 360:</div><div style="text-align: left; "> Métodos Numéricos en Vibroacústica</div></td>
#   <td><div style="text-align: center; ">Mario González</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">IMPT 330:</div><div style="text-align: left; "> Ciencia e Ingeniería de los Materiales</div></td>
#   <td><div style="text-align: center; ">Loreto Troncoso, Gabriela Martínez</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">IMPT 331:</div><div style="text-align: left; "> Transferencia de Calor y Masa: Simulación y Aplicaciones</div></td>
#   <td><div style="text-align: center; ">Rogelio Moreno</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#   <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">IMPT 340:</div><div style="text-align: left; "> Elementos Finitos en Vibraciones</div></td>
#   <td><div style="text-align: center; ">Gabriela Martínez</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 322:</div><div style="text-align: left; "> Materiales Acústicos</div></td>
#   <td><div style="text-align: center; ">Rodolfo Venegas</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">ACUS 337:</div><div style="text-align: left; "> Análisis Modal</div></td>
#   <td><div style="text-align: center; ">José Luis Barros</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">170</div></td>
#   <td><div style="text-align: center; ">208</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">8</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">INFO 320:</div><div style="text-align: left; ">Redes Neuronales y Aprendizaje Bayesiano</div></td>
#   <td><div style="text-align: center; ">Pablo Huijse</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">92</div></td>
#   <td><div style="text-align: center; ">130</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">5</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">INFO 338:</div><div style="text-align: left; ">Procesamiento de Señales Avanzado y Métodos de Kernel</div></td>
#   <td><div style="text-align: center; ">Pablo Huijse</div></td>
#   <td><div style="text-align: center; ">Electivo</div> </td>
#   <td><div style="text-align: center; ">38</div></td>
#   <td><div style="text-align: center; ">92</div></td>
#   <td><div style="text-align: center; ">130</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">5</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
# </tr>
#    <tr style="outline: thin solid">
#   <td colspan="9"><div style="text-align: left; "><strong><em>Otras actividades obligatorias del programa</em></strong></div>
# </td>
# </tr>
#   <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">Idioma*</div></td>
#   <td><div style="text-align: center; ">Profesores del programa de inglés de la Dirección de Estudios de Postgrado</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">26</div></td>
#   <td><div style="text-align: center; ">104</div></td>
#   <td><div style="text-align: center; ">130</div></td>
#   <td><div style="text-align: center; ">Sin créditos UACh *</div></td>
#   <td><div style="text-align: center; ">5</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
# </tr>
#   <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">Proyecto de Tesis*</div></td>
#   <td><div style="text-align: center; ">Profesores del claustro del programa</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">75</div></td>
#   <td><div style="text-align: center; ">78</div></td>
#   <td><div style="text-align: center; ">Sin créditos UACh *</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">Segundo semestre</div></td>
# </tr>
#   <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">Tesis*</div></td>
#   <td><div style="text-align: center; ">Comisión Evaluadora de cada estudiante + Director del Programa</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">76</div></td>
#   <td><div style="text-align: center; ">1276</div></td>
#   <td><div style="text-align: center; ">1352</div></td>
#   <td><div style="text-align: center; ">10</div></td>
#   <td><div style="text-align: center; ">52</div></td>
#   <td><div style="text-align: center; ">Tercer y cuarto semestre</div></td>
# </tr>
#   <tr style="outline: thin solid">
#   <td><div style="text-align: left; ">Examen de Grado*</div></td>
#   <td><div style="text-align: center; ">Director de la Escuela de Graduados
# + Comisión Evaluadora de cada estudiante</div></td>
#   <td><div style="text-align: center; ">Obligatorio</div> </td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">75</div></td>
#   <td><div style="text-align: center; ">78</div></td>
#   <td><div style="text-align: center; ">Sin créditos UACh *</div></td>
#   <td><div style="text-align: center; ">3</div></td>
#   <td><div style="text-align: center; ">Cuarto semestre</div></td>
# </tr>
#   <tr style="outline: thin solid">
#   <td colspan="9"><div style="text-align: left; "><sup>*</sup> Las actividades Idioma, Proyecto de Tesis y Examen de Grado corresponden a hitos en el Plan de Estudios y se califican cualitativamente como aprobadas (A) o reprobadas (R). En el caso de la actividad Idioma, los estudiantes rinden un examen de suficiencia de inglés antes del término del periodo lectivo. Aquellos que no aprueban la suficiencia de idioma mediante el examen, deben cursar el Programa de Inglés para Estudiantes de Postgrado habilitado desde la Dirección de Estudios de Postgrado.</div>
# </td>
# </table>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
