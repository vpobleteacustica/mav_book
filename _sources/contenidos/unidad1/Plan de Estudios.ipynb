# %% [markdown]
# # Plan de Estudios

# %% [markdown]
# <table align="left">
#     <thead>
#     <tr><td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);"><strong>SEMESTRE 1 *</strong></div></div>
#     <td class="left"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);"><strong>SEMESTRE 2</strong></div></div>
#     <td class="left"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);"><strong>SEMESTRE 3</strong></div></div>
#     <td class="left"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);"><strong>SEMESTRE 4</strong></div></div>
#     </tr>
# </thead>
# <tbody>
# <tr>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">ACUS 301:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Vibroacústica</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">(1 crédito)</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div></td>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Curso</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Electivo:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">número 1</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">**</div></div></td>
# <td rowspan = "5"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Tesis</div></div></td>
# <td rowspan = "4"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Tesis</div></div></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">ACUS 302:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Instrumentación en</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">acústica y vibraciones</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">(1 crédito)</div></div></td>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Curso</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Electivo:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">número 2</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">**</div></div></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">MATM 310:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Métodos matemáticos en</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">ingeniería</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">(4 créditos)</div></div></td>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Curso</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Electivo:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">número 3:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">**</div></div></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">GCIN 331:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Seminario de investigación e</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">innovación en ingeniería</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">(1 crédito)</div></div></td>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">ACUS 397:</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Seminario de Tesis</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">(2 créditos)</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">***</div></div></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Idioma</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">****</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div></td>
# <td class="center"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Proyecto de Tesis</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">****</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div></td>
# <td rowspan = "1"><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">Examen de Grado</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">****</div></div><div style="text-align: center; "><div style="background-color: rgb(212, 212, 212);">-</div></div></td>
# </tr>
#
# </tbody>
# </table>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
#
# $^{*}$Los cursos del currículum obligatorio se dictan cada año en el periodo agosto-diciembre que es, formalmente, el periodo de inicio de las actividades del programa.
#
# $^{**}$ Los estudiantes deben completar 9 créditos en cursos electivos. Si bien el MAV cuenta con una oferta específica de asignaturas electivas propias y directamente afines a los objetivos, perfil de egreso y líneas de investigación del programa, en la Universidad Austral de Chile la oferta íntegra de cursos de postgrado se encuentra disponible como optativos para los estudiantes de los demás programas, en la medida en que tales asignaturas dispongan de cupos y los interesados cumplan con los requisitos exigidos en dichos cursos.
#
# $^{***}$ A contar de 2018, los estudiantes que ingresan al programa vía articulación pregrado-magíster, cursan esta actividad como trabajo final de titulación.
#
# $^{****}$ Las actividades Idioma, Proyecto de Tesis y Examen de Grado corresponden a hitos en el Plan de Estudios y se califican cualitativamente como aprobadas (A) o reprobadas (R). En el caso de la actividad Idioma, los estudiantes rinden un examen de suficiencia de inglés. Quienes no aprueban el examen, deben cursar el Programa de Inglés para Estudiantes de Postgrado habilitado desde la Dirección de Estudios de Postgrado.

# %% [markdown]
# ## Actividades curriculares (resguardar consistencia con información del Anexo 5)
#
# ### Actividades curriculares
#
# <table align="left">
#     <thead>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
#     <tr><td class="center"><div style="text-align: center; "><strong>Actividades curriculares</strong></div>
#     <td class="left"><div style="text-align: center; "><strong>Créditos</strong></div>
#     </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="center"><div style="text-align: left; ">Cursos obligatorios</div></td>
# <td class="center"><div style="text-align: center; ">10</div></td>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Cursos electivos</div><div style="text-align: center; "></div></td>
# <td class="center"><div style="text-align: center; ">9</div><div style="text-align: center; "></div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Seminarios (2)</div></td>
# <td class="center"><div style="text-align: center; ">3</div><div style="text-align: center; "></div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Idioma (suficiencia de inglés)*</div><div style="text-align: center; "></div></td>
# <td class="center"><div style="text-align: center; ">Sin créditos</div><div style="text-align: center; "></div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Proyecto de Tesis*</div></td>
# <td class="center"><div style="text-align: center; ">Sin créditos</div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Tesis*</div></td>
# <td class="center"><div style="text-align: center; ">10</div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="center"><div style="text-align: left; ">Examen de Grado*</div></td>
# <td class="center"><div style="text-align: center; ">Sin créditos</div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="left"><div style="text-align: left; "><div style="background-color: rgb(212, 212, 212);">Total creditaje del programa, según definición de</div></div><div style="text-align: left; "><div style="background-color: rgb(212, 212, 212);">crédito/unidad equivalente propia</div></div></td>
# <td class="center"><div style="text-align: center; ">32</div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# <tr>
# <td class="left"><div style="text-align: left; ">Duración teórica del programa
# </div></td>
# <td class="center"><div style="text-align: center; ">Cuatro semestres
# </div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# <tr>
# <td class="left"><div style="text-align: left; ">Duración total en horas de trabajo efectivo presencial</div><div style="text-align: left; ">y no presencial (horas cronológicas)</div></td>
# <td class="center"><div style="text-align: center; ">3.120</div></td>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="left"><div style="text-align: left; ">Definición crédito/unidad equivalente propia del</div><div style="text-align: left; ">programa</div></td>
# <td class="left"><div style="text-align: left; "><strong>“Crédito [UACh]”</strong> es una expresión</div><div style="text-align: left; ">cuantitativa del trabajo del estudiante.</div><div style="text-align: left; ">Se asigna un crédito por (a) cada hora</div><div style="text-align: left; "> pedagógica de clase teórica o (b) cada</div><div style="text-align: left; ">dos horas pedagógicas prácticas</div><div style="text-align: left; ">con sus correspondientes horas</div><div style="text-align: left; "> de estudio. Una hora pedagógica</div><div style="text-align: left; ">= 0,75 horas cronológicas. Un semestre</div><div style="text-align: left; "> tiene una duración oficial de 17 semanas.</div></td>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="left"><div style="text-align: left; ">Definición del crédito Sistema de Créditos</div><div style="text-align: left; ">Transferibles (SCT)</div></td>
# <td class="left"><div style="text-align: left; ">1 crédito SCT en la Universidad Austral</div><div style="text-align: left; ">de Chile equivale a 26 horas de trabajo</div><div style="text-align: left; ">real del estudiante (considerado el tiempo</div><div style="text-align: left; ">de trabajo presencial y el tiempo de trabajo</div><div style="text-align: left; ">autónomo). Los créditos SCT para cada</div><div style="text-align: left; ">actividad se expresan en números enteros.</div><div style="text-align: left; "> Los valores de las horas cronológicas de las</div><div style="text-align: left; ">actividades informadas en la Tabla 3.3.2b </div><div style="text-align: left; "> corresponden a la duración total de la carga</div><div style="text-align: left; ">horaria de cada actividad.</div></td>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tr>
# <tr>
# <td class="left"><div style="text-align: left; "><strong>Total equivalencia del creditaje del programa,</strong>
# </div><div style="text-align: left; "><strong>según el Sistema de Créditos Transferibles</strong></div></td>
# <td class="center"><div style="text-align: center; "><strong>120</strong>
# </div></td>
# </tr>
# <tr style="border-bottom:1px solid black">
#     <td colspan="100%"></td>
# </tbody>
# </table>
#
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
