# %% [markdown]
# # Identificación del Programa

# %% [markdown]
# <font size="2" face="Arial" >
# <table align="left" style="width:95%" border="1">
#   <tr style="outline: thin solid">
#   <td colspan="2"><div style="text-align: left; "><strong>1. IDENTIFICACIÓN DEL PROGRAMA</strong></div>
# </td>
# </tr>
# <tbody>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Nombre del programa</div></td>
#   <td><div style="text-align: left; ">Magíster en Acústica y Vibraciones</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Grado(s) otorgado(s)</div></td>
#   <td><div style="text-align: left; ">Magíster en Acústica y Vibraciones</div></td>
#  </tr>
#   <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Carácter u orientación</div></td>
#   <td><div style="text-align: left; ">Académico</div></td>
#  </tr>
#   <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Universidad/Institución</div></td>
#   <td><div style="text-align: left; ">Universidad Austral de Chile</div></td>
#  </tr>
#   <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Facultad/Instituto o equivalente</div></td>
#   <td><div style="text-align: left; ">Facultad de Ciencias de la Ingeniería</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Departamento/Escuela o equivalente</div></td>
#   <td><div style="text-align: left; ">Escuela de Graduados</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Año de creación</div></td>
#   <td><div style="text-align: left; ">2008</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Año de inicio de actividades
# </div></td>
#   <td><div style="text-align: left; ">2008</div></td>
#  </tr>
#   <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Sedes</div></td>
#   <td><div style="text-align: left; ">Campus Miraflores, Valdivia</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Modalidad</div></td>
#   <td><div style="text-align: left; ">Presencial</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Jornadas</div></td>
#   <td><div style="text-align: left; ">Presencial</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Dedicación </div></td>
#   <td><div style="text-align: left; ">Exclusiva</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Horario clases</div></td>
#   <td><div style="text-align: left; ">Lunes a viernes, de 8:10 a 13:00 hrs. y de 14:10 a 19:00 hrs.</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Dirección</div></td>
#   <td><div style="text-align: justify; ">Edificio 6000, Campus Miraflores, Universidad Austral de Chile, Valdivia, Chile</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Director/Coordinador </div></td>
#   <td><div style="text-align: left; ">Dr. Víctor Poblete Ramírez</div></td>
#  </tr>
#  <tr style="outline: thin solid">
#   <td bgcolor="lightgray"><div style="text-align: left; ">Integrantes comité académico</div></td>
#   <td><div style="text-align: justify; ">Dr. Víctor Poblete Ramírez (Director de Programa), Dr. Rodolfo Venegas Castillo, Dr. Jorge Arenas Bermúdez, Dr. Enrique Suárez Silva, Dr. Mario González Montenegro</div></td>
#  </tr>
#  </tbody>
# </table>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
